# %%
from data import corrupt_mnist
from data import show_image_and_target
import torch

# %%
# Load the dataset
train_set, test_set = corrupt_mnist()

# Create a DataLoader to load a batch of images and labels
trainloader = torch.utils.data.DataLoader(train_set, batch_size=16, shuffle=True)

# Get a batch of images and labels
images, labels = next(iter(trainloader))

# Show the images and their labels
show_image_and_target(images, labels)
